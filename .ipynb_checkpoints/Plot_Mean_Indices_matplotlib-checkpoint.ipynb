# %% [markdown]
# Patrick BROCKMANN - LSCE (Climate and Environment Sciences Laboratory)<br>
# <img align="left" width="40%" src="http://www.lsce.ipsl.fr/Css/img/banniere_LSCE_75.png" \><br><br>
# <hr>

# %%
#http://webportals.ipsl.jussieu.fr/thredds/catalog/EUROCORDEX/output/output_WPS/ensemble/catalog.html

url = "http://webportals.ipsl.jussieu.fr/thredds/catalog/EUROCORDEX/output/output_WPS/ensemble"

# %%
# Read the URL that display the XML catalog of indices
import urllib2

xmlCatalogEnsemble = url + "/catalog.xml"

file = urllib2.urlopen(xmlCatalogEnsemble)
data = file.read()
file.close()

# Build the list of indices
from xml.dom.minidom import parseString

dom = parseString(data)
a=dom.getElementsByTagName('catalogRef')

indices=[]
for i in range(len(a)):
        indices.append(a[i].getAttribute('xlink:title'))
        
print indices
# Out:
# [u'CDD', u'CSU', u'ID', u'R20mm', u'RR', u'RX5day', u'SU', u'TX', u'TXx']

# %%
# Read the URL that display the XML catalog of experiments
xmlCatalogEnsemble = url + "/" + indices[0] + "/catalog.xml"

file = urllib2.urlopen(xmlCatalogEnsemble)
data = file.read()
file.close()

# Build the list of indices
dom = parseString(data)
a=dom.getElementsByTagName('catalogRef')

experiments=[]
for i in range(len(a)):
        experiments.append(a[i].getAttribute('xlink:title'))
        
print experiments
# Out:
# [u'rcp45', u'rcp85']

# %%
# Read the URL that display the XML catalog of countries
xmlCatalogEnsemble = url + "/" + indices[0] + "/" + experiments[0] + "/catalog.xml"

file = urllib2.urlopen(xmlCatalogEnsemble)
data = file.read()
file.close()

# Build the list of indices
dom = parseString(data)
a=dom.getElementsByTagName('catalogRef')

countries=[]
for i in range(len(a)):
        countries.append(a[i].getAttribute('xlink:title'))
        
print countries
# Out:
# [u'ALB', u'AUT', u'BEL', u'BGR', u'BIH', u'BLR', u'CHE', u'CYP', u'CZE', u'DEU', u'DNK', u'ESP', u'EST', u'FIN', u'FRA', u'GBR', u'GRC', u'HRV', u'HUN', u'IRL', u'ISL', u'ITA', u'KOS', u'LTU', u'LUX', u'LVA', u'MDA', u'MKD', u'MLT', u'MNE', u'NLD', u'NOR', u'POL', u'PRT', u'ROU', u'SRB', u'SVK', u'SVN', u'SWE', u'UKR']

# %%
import matplotlib
import random

def random_color():                  # find a color that is dark enought (L <= 0.5)
    luminance = 1
    while (luminance > 0.5):
        color = random.choice(matplotlib.colors.cnames.keys())
        #print color
        R,G,B = matplotlib.colors.hex2color(matplotlib.colors.cnames[color]) 
        luminance = (0.299*R + 0.587*G + 0.114*B)
    return color

print random_color()
# Out:
# magenta

# %%
colors=[]
for i in range(1,20):
    colors.append(random_color())

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import netCDF4
from netCDF4 import num2date, date2num, date2index
# %matplotlib inline

fig1, ax1 = plt.subplots(figsize=(10,4))

def plot(subplot, indice, experiment, country, percentile=True, title=None, legend=None, color=None, verbose=False):

    #print indice, experiment, country
    
    if color==None:
        color = random_color()
    
    plotMean = True
    try:
        file = url.replace("catalog", "dodsC") + "/" + indice + "/" + experiment + "/" + country + "/median_1971-2100_yr.nc"
        f = netCDF4.Dataset(file)
        try: 
            NumberEnsembles = f.NumberEnsembles
        except:
            NumberEnsembles = "?"
        try:
            if verbose:
                print "%s = %s [%s]" %(indice, f.variables[indice].long_name, f.variables[indice].units)
        except:
            pass
        varMean = f.variables[indice][:,0,0]
        times = f.variables["time"]
        dates = num2date(times[:], times.units, calendar="standard")
        f.close()
    except:
        plotMean = False
        print "Not available: " + file
        return

    try:
        file = url.replace("catalog", "dodsC") + "/" + indice + "/" + experiment + "/" + country + "/pctl33_1971-2100_yr.nc"
        f = netCDF4.Dataset(file)
        varPctl33 = f.variables[indice][:,0,0]
        f.close()
        file = url.replace("catalog", "dodsC") + "/" + indice + "/" + experiment + "/" + country + "/pctl66_1971-2100_yr.nc"
        f = netCDF4.Dataset(file)
        varPctl66 = f.variables[indice][:,0,0]
        f.close()    
    except:
        percentile = False
        print "Percentile files not available"

    subplot.grid(True)

    if legend == None:
        legend = "%s / %s / %s (%s)" %(indice, experiment, country, NumberEnsembles)
    if title:
        plt.title(title)

    if percentile:
        subplot.fill_between(dates, varPctl33, varPctl66, facecolor=color, edgecolor=color, alpha=0.3)
    if plotMean:
        subplot.plot(dates, varMean, color=color, lw=2, label=legend)
    subplot.legend()
        
plot(ax1, "RR", "rcp85", "DEU", title="EURO-CORDEX Indices", percentile=False, verbose=True)
# Out:
# RR = Precipitation sum [mm]

# %%
from IPython.html.widgets import interact

@interact(indice=(indices), experiment=(experiments), country=(countries))
def plot_interact(indice="TX", experiment="rcp45", country="DEU", percentile=False):
    fig2, ax2 = plt.subplots(figsize=(10,4))
    plot(ax2, indice, experiment, "FRA", percentile, color=colors[0], verbose=True)                  # always compare to FRA 
    plot(ax2, indice, experiment, country, percentile, color=colors[1])
# Out:
# TX = Mean of daily maximum temperature [Celcius]
